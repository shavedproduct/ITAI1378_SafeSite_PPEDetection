# %%
# Install the required library
# !pip install ultralytics

# %%
# Import YOLO 
from ultralytics import YOLO

# load yolo
model = YOLO('yolov8n.pt') 

# Run a test prediction
results = model.predict(source='https://ultralytics.com/images/bus.jpg', save=True)
# Out:
# ...
#
# ...
# image 1/1 c:\Users\mat61\Downloads\school2026summertests\ITAI1378_SafeSite_PPEDetection\notebooks\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 148.6ms
# Speed: 10.0ms preprocess, 148.6ms inference, 33.0ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to C:\Users\mat61\Downloads\school2026summertests\ITAI1378_SafeSite_PPEDetection\notebooks\runs\detect\predict

# %%
# !pip install roboflow

from roboflow import Roboflow
# NOTE: API key removed for GitHub security. 
rf = Roboflow(api_key="X6GIhxNfRggZmrIRhF7n")
project = rf.workspace("yami-dzhfx").project("construction-ppe-qw7qk")
version = project.version(1)
dataset = version.download("yolov8")

print("Dataset downloaded successfully!")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Construction-PPE-1 in yolov8:: 100%|██████████| 4581/4581 [00:02<00:00, 1829.71it/s]
# Dataset downloaded successfully!

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os
import random


image_folder = f"{dataset.location}/train/images"

# random image
random_image = random.choice(os.listdir(image_folder))
img_path = os.path.join(image_folder, random_image)

# show the image
img = mpimg.imread(img_path)
plt.figure(figsize=(10, 8))
plt.imshow(img)
plt.axis('off')
plt.title("Sample Construction Site Image from Dataset")
plt.show()
